# %% [markdown]
# SEABORN LEARNING BEFORE MODEL TRAINING

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# Matplotlib basics

# %%
fig = plt.figure()
ax= fig.add_axes([0.1,0.1,1,1])
ax.plot(x,y)
plt.savefig("basicplot.png")

# %% [markdown]
# Working With Image

# %% [markdown]
# Optional Desigining

# %%
import numpy as np
import matplotlib.pyplot as plt

xaxis = np.linspace(0, 5, 11)

fig, ax = plt.subplots(figsize=(12, 6))

# Line widths
ax.plot(xaxis, xaxis+1, color="red", linewidth=0.25)
ax.plot(xaxis, xaxis+2, color="red", linewidth=0.5)
ax.plot(xaxis, xaxis+3, color="red", linewidth=1.0)
ax.plot(xaxis, xaxis+4, color="red", linewidth=2.0)

# Linestyles
ax.plot(xaxis, xaxis+5, color="green", lw=3, ls='-')
ax.plot(xaxis, xaxis+6, color="green", lw=3, ls='-.')
ax.plot(xaxis, xaxis+7, color="green", lw=3, ls=':')

# Custom dash
line, = ax.plot(xaxis, xaxis+8, color="black", lw=1.5)
line.set_dashes([5, 5, 15, 5])

# Markers
ax.plot(xaxis, xaxis+9,  color="blue",   lw=3, ls='-', marker='+')
ax.plot(xaxis, xaxis+10, color="blue",   lw=3, ls='',  marker='o')
ax.plot(xaxis, xaxis+11, color="blue",   lw=3, ls='-', marker='s')
ax.plot(xaxis, xaxis+12, color="blue",   lw=3, ls='',  marker='1')

# Marker styling
ax.plot(xaxis, xaxis+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(xaxis, xaxis+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(xaxis, xaxis+15, color="purple", lw=1, ls='-', marker='o',
        markersize=8, markerfacecolor="red")

ax.plot(xaxis, xaxis+16, color="purple", lw=1, ls='-', marker='s',
        markersize=8, markerfacecolor="yellow",
        markeredgewidth=3, markeredgecolor="green")

plt.show()

# %% [markdown]
# LET'S START WITH SEABORN

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# WHAT ARE THE PLOTS I AM GOING TO LEARN
# * distplot
# * jointplot
# * pairplot
# * rugplot

# %%
df= sns.load_dataset('tips')
df

# %%
df['size'].unique()

# %%
plt.subplot(1,2,1)
sns.histplot(df['total_bill'],bins =20,kde = True) 
plt.subplot(1,2,2)
sns.histplot(df['tip'],bins=20)

# %%
#JOINTPLOT 
plt.subplot(1,2,1)
sns.jointplot(x='total_bill',y='tip',data=df,kind='hex')
plt.subplot(1,2,2)
sns.jointplot(x='total_bill',y='tip', data= df,kind='reg')

# %%
# PAIRLOT
sns.pairplot(df,hue='sex',palette='flare')

# %%
sns.pairplot(df ,hue='size',palette='rainbow')

# %%
#RUGPLOT 
sns.rugplot(df['total_bill'])

# %% [markdown]
# TILL NOW I LEARNABOUT QUANTITATIVE PLOTS

# %% [markdown]
# LET'S START Categorical Plots

# %%
df= sns.load_dataset('tips')
df

# %%
sns.countplot(x=df['sex'],hue= df['smoker'])

# %%
#BARPLOT 
sns.barplot(x= df['sex'],y=df ['tip'], estimator=np.sum)

# %%
#BOXPLOT
sns.boxplot(x=df['tip'], y=df['day'],palette='rocket')

# %% [markdown]
# boxplots and violinplots are used to shown the distribution of categorical data .A box plot shpw the distribution of the quantitatve data in a way that facilitates camparison between variable or across levels of a cateforica; variable .

# %%
sns.violinplot(x='day',y='total_bill', data=df)

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("heart.csv")
df.tail()

# %% [markdown]
# EDA(EXPLORATRY DATA ANALYSIS)

# %%
df.columns

# %%
df.info()

# %% [markdown]
# for eda i check the dataype in info , check columns, duplicates .

# %%
df.duplicated().sum() 
df['ChestPainType'].value_counts()
df.isnull().sum()

# %%
def plotting(var,num):
    plt.subplot(2,2,num)
    sns.histplot(df[var],kde= True)

plotting('Age',1)
plotting('RestingBP',2)
plotting('Cholesterol',3)
plotting('MaxHR',4)

plt.tight_layout() # i checked there is cholestrol of people's which is 0, but cholesterol can't be 0. so i get the mean of 
                    # values other than the 0 and replaced it with the 0. so now the date is ok to predict . same for restingbp.

# %%
ch_mean = df.loc[df['Cholesterol'] != 0 ,'Cholesterol'].mean()
ch_mean

# %%
df['Cholesterol'] = df['Cholesterol'].replace(0,ch_mean)
df['Cholesterol'] = df['Cholesterol'].round(2)

# %%
rb_mean = df.loc[df['RestingBP'] != 0 ,'RestingBP'].mean()
rb_mean
df['RestingBP'] = df['RestingBP'].replace(0,ch_mean)
df['RestingBP'] = df['RestingBP'].round(2)

# %%
def plotting(var,num):
    plt.subplot(2,2,num)
    sns.histplot(df[var],kde= True)

plotting('Age',1)
plotting('RestingBP',2)
plotting('Cholesterol',3)
plotting('MaxHR',4)

plt.tight_layout()

# %% [markdown]
# Categorical Data

# %%
sns.countplot(x= df["ChestPainType"], hue= df['HeartDisease'])

# %%
sns.countplot(x = df['Sex'],  hue= df['HeartDisease'])

# %%
df.head()

# %%
df_encode =pd.get_dummies(df,drop_first= True)
df_encode

# %%
df_encode = df_encode.astype(int)
df_encode

# %%
from sklearn.preprocessing import StandardScaler
num_cols =['Age','RestingBP','Cholesterol','MaxHR']
scaler = StandardScaler()
df_encode[num_cols] = scaler.fit_transform(df_encode[num_cols])
df_encode.head()

# %% [markdown]
# NOW I AM CREATING A HEART DISEASE PREDICTION MODEL

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
x= df_encode.drop('HeartDisease', axis= 1)
y = df_encode['HeartDisease']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
scaler = StandardScaler()

# %%
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.fit_transform(x_test)

# %%
models = {
    'LogisticRegression': LogisticRegression(),
    'NaiveBayes': GaussianNB(),
    'KNN' : KNeighborsClassifier(),
    'DecisionTreeClassifier': DecisionTreeClassifier(),
    'SVM' : SVC()
}

results = []
for name, model in models.items(): 
    model.fit(x_train_scaled, y_train)
    y_pred = model.predict(x_test_scaled)
    acc = accuracy_score(y_test, y_pred)
    f_score = f1_score(y_test, y_pred)
    results.append ({
        'model' : name,
        'accuracy_score' : round(acc,4),
        'f1_score' : round(f_score,4)
    })

# %%
results

# %%
import joblib
joblib.dump(models['KNN'], 'KNN_heart.pkl')
joblib.dump(scaler, 'scaler.pkl')
joblib.dump(x.columns.tolist(), 'columns.pkl')

# %% [markdown]
# SO THE MODEL IS FULLY TRAINED AND I CREATED A HEART DISEASE PRECTING APPLICATION .
